# %% [markdown]
# # Week 2.2 Lab: GitHub + Colab + GCP Integration

# %% [markdown]
# In this guided lab, you will practice setting up your **team workflow** by connecting GitHub, Google Colab, Google Drive,
# and Google Cloud Platform (GCP). By the end, you will have a working notebook saved in your team repo and authenticated to GCP.
#
# **Learning Objectives:**
# - Create and configure a GitHub account (if not already done).
# - Create or join your **team repository** on GitHub.
# - Connect Colab to Google Drive for data and notebook persistence.
# - Authenticate Colab to access GCP services (BigQuery, Storage).
# - Save your Colab notebook to your GitHub repository.

# %% [markdown]
# ## 1. GitHub Account & Team Repository

# %% [markdown]
# 1. Go to [https://github.com](https://github.com) and create an account (if you don’t already have one).
# 2. One teammate should create a new repository (e.g., `MGMT467_TeamX`), set it to **Private**, and add collaborators.
# 3. Each team member should **accept the invite** to the repo.
# 4. Confirm by cloning the repo locally or simply viewing it online.
#
# :bulb: Later labs will rely on this shared repo for collaboration.

# %% [markdown]
# ## 2. Connect Colab to Google Drive

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Check contents (optional)
# !ls /content/drive/MyDrive
# Out:
# Mounted at /content/drive
#  03-Joe_Hisaishi-One_Summer_39_s_Day.pdf
# '128_Harv._L._Rev._1747,_ (1).DOC.gdoc'
#  128_Harv._L._Rev._1747,_.DOC.gdoc
# '13th netflix documentary.gdoc'
#  1737144587095.jpg
# '176 project code.pdf'
# '180degrees interview sheet.gdoc'
#  20028-nba-with-logo-ppt-template.gslides
#  20028-nba-with-logo-ppt-template.potx
#  20161001_171553.jpg
# '2022 og squad form.gform'
# '2023 seniors live band audition form (File responses)'
# '2023 seniors live band audition form.gform'
#  2024_06_15_11_11_56_1.mp3
#  2024_06_15_11_13_57_1.mp3
# '2024 fall career fair.gdoc'
# '2024 internship.gsheet'
# '2 16 PSYCH TESTPEOPLE.gdoc'
# '254 notes.gdoc'
# '26 len'
# '26 letters thingy'
# '305 final cheat sheet.gdoc'
# '305 midterm 1 cheat sheet.gdoc'
# '324 case 2.gdoc'
# '324 final cheat sheet.gdoc'
# '324 quiz 1 cheat sheet.gdoc'
# '382 review session (combine later).gdoc'
# '382 study guide.gdoc'
# '382 study guide.pdf'
#  3F8CDF04-1F44-4DB7-9893-7E0FF1ADBEF2.jpeg
# '3rd quarter warmups.gdoc'
# '45_Ariz._L._Rev._1067,_ (1).DOC.gdoc'
#  45_Ariz._L._Rev._1067,_.DOC.gdoc
#  4.png
#  589d9aa61887199f0dc76ea17ba9039f.mp4
# '6123389483426903958 (1).gdoc'
#  6123389483426903958.gdoc
#  6123389483426903958.pdf
# '6-12 gow questions.gdoc'
# '7 24.gdoc'
# '8 19 notes.gdoc'
# '9 7 party costs and list.gsheet'
# 'aaa payment.png'
# 'Absolute Monarchs.pdf'
#  absolve.gdoc
# 'act 1 questions.gdoc'
# 'Act 3 and 4Proc questions.gdoc'
# 'Act II questions Crucible.gdoc'
# 'Affirmative debate case.gdoc'
#  ahskdfkajs
# 'Alexander Graham Bell.gdoc'
# 'Algebra 1 Lesson 3: Graphing Equations, Inequalities Part III, and Systems of Equations Part II.gslides'
# 'Annie becomes jacked af.gsheet'
# 'AP MACRO NOTESSS.gdoc'
#  apostrophe.gslides
# 'Appeasement and the Start of World War 2.gdoc'
# 'AP schedule.gsheet'
# 'background music.mp3'
# 'BASS TABS WOO.gdoc'
# 'beachesfinal - Made with Clipchamp_1750579188136.mp4'
# 'Beaches - Made with Clipchamp_1750578395387.mp4'
# 'Beef Jerky.gdoc'
# 'Berlioz Leonard Chiu AO.m4a'
# 'best self assignment project.gdoc'
# 'bleep bloop bleep.gdoc'
# 'Blocks for Israeli Palestinian topic.gdoc'
# 'blocks for missile defense topic.gdoc'
# 'boegman litany poem.jpg'
# 'Book Report 2 presentation by Leonard Chiu P2 nioseras.gslides'
# 'BPC 2021 Chapter Evals (dragged) 8.pdf'
# 'BPC elevator pitch.gdoc'
# 'BROTHER INTERVIEWS.gsheet'
#  bruh
# 'BUDGET PROEJCT BALHEIHOIH.gdoc'
# 'Business core points.gdoc'
# 'business law test 3 notes.gdoc'
# 'Business Model analysis.gsheet'
# 'BUY THIS FOR NO REASON.gsheet'
#  Calculators.ipynb
# 'CamScanner 01-25-2021 15.08 - Page 1.jpg'
# 'CamScanner 01-25-2021 15.08 - Page 2.jpg'
# 'CamScanner 01-25-2021 15.08 - Page 3.jpg'
# 'CamScanner 01-25-2021 15.08 - Page 4.jpg'
# 'CamScanner 01-25-2021 15.13 - Page 1.jpg'
# 'CamScanner 01-25-2021 15.13 - Page 2.jpg'
# 'CamScanner 01-25-2021 15.13 - Page 3.jpg'
# 'CamScanner 01-25-2021 15.13 - Page 4.jpg'
# 'CamScanner 01-25-2021 15.19 - Page 1.jpg'
# 'CamScanner 01-25-2021 15.19 - Page 2.jpg'
# 'CamScanner 01-27-2021 09.32 - Page 4.jpg'
# 'CamScanner 02-13-2021 17.10 - Page 1.jpg'
# 'CamScanner 02-13-2021 17.33 - Page 7.jpg'
# 'CamScanner 05-19-2021 12.40 - Page 1.jpg'
# 'Capital Gains Tax Blocks.gdoc'
# 'Capital Gains Tax debate topic aff.gdoc'
# 'capital gains tax.gdoc'
#  cat.jpg
# 'Ch 3 and Ch 5 questions TSOR.gdoc'
# 'Ch. 9 Notes 3rd set (1).ppt'
# 'Ch. 9 Notes 3rd set.ppt'
# 'Chapter 26 Response Leonard Chiu P6.gdoc'
# 'Chapter 6 and 7 TSOR questions even.gdoc'
# 'Chapters 18-26 questions.gdoc'
# 'chem notes.gdoc'
#  Chiu_Leonard.pdf
# 'Chiu Questions for 8 25 Reading.gdoc'
# 'Claim: The mission creek ecosystem is unhealthy.gdoc'
# 'Clap for way back then.m4a'
# 'Clash Royale presentation.gslides'
#  Classroom
# 'Class Talks.gsheet'
#  Clouds.gdoc
# 'Coffee chat with Susan from Capital One.gdoc'
# 'Colab Notebooks'
# 'COLLEGE LINKS AND DATES.gdoc'
# 'College supplementals.gdoc'
# 'College Teacher Recommendation.gdoc'
# 'com 114 notes.gdoc'
# 'communism v capitliasm poster.gslides'
# 'Con Case missle defense len c.gdoc'
# 'Con debate case January pf topic.gdoc'
# 'connector role  .gdoc'
# 'cooking ingredients list.gdoc'
# 'Copy of A SAT workout.gdoc'
# 'copy of copy.gdoc'
# 'Copy of Copy of  Internship Tracker 2025 - Leonard Chiu.gsheet'
# 'Copy of Cream, Green, and Black Geometric Blocks Clean Minimal Presentation .gslides'
# 'Copy of Financial Model Template by Slidebean.gsheet'
# 'Copy of IMG_1391.MOV'
# 'Copy of Leonard interview questions.gdoc'
# 'Copy of Statistics & Results Infographics by Slidesgo.gslides'
# 'Copy of Study Guide – Chapters 8-12.gdoc'
# 'cost kearns business project.gsheet'
# 'COVER LETTER.gdoc'
# 'Crackers Recipe.gdoc'
# 'Crossword Puzzle.gdoc'
# 'CS176 documentation.gdoc'
#  CS176_final_project.ipynb
# 'CS 235 excel notes.gdoc'
# 'Cuban Embargo'
# 'CYS 2022 SECRET SANTA WISHLIST.gsheet'
# 'CYS Audition'
# 'CYS BRASS SECTION WISHLIST 2022-2023.gsheet'
# 'Dangling modifiers.gdoc'
# 'data journey essay.gdoc'
# 'Debate case (con).gdoc'
# 'Debate case.gdoc'
# 'debate plus speech'
# 'DECA makeup roleplay.mp4'
# 'DECA mock PBM cluster exam.gdoc'
#  Decathon.gslides
# 'Demon Slayer fight scene ideas.gdoc'
# 'Dialogflow CX notes.gdoc'
# 'diep.io gaming artice for feb eyops.gdoc'
# 'diss ur mom.gdoc'
# 'Do not go gentle into the night 8 steps.gdoc'
# 'do not go gentle.jpg'
# 'Doster Brainstorming.gdoc'
# 'Down Syndrome .gslides'
# 'down syndrome project.gdoc'
#  Draft.docx
# 'dr. erskine parts.gdoc'
# 'Drowning the Oceans in Plastic essay.gdoc'
# 'Drum way back then.m4a'
# 'DSB resume builder notes.gdoc'
# 'dulce et decorum est short essay.gdoc'
#  E43569D4-78C3-4782-B702-C2BBB8FD78AF.jpeg
# 'eaps final guide.gdoc'
# 'Econ list.gsheet'
# 'Election of 1800 info I guess.gdoc'
# 'electoral college and national popular vote topic notes.gdoc'
# 'Email draft for businesses outside of IN.gdoc'
# 'English Conventions Assesment.gdoc'
# 'english final.gdoc'
# 'ESB chip idea.gdoc'
# 'ESB Script.gdoc'
# 'Essay Error Corrections Leonard Chiu Period 6  - Page 2.jpg'
#  estabrook
# 'estabrook vocab.gdoc'
# 'ETHIOPIA book pamphlet.gdoc'
# 'Exemption vaccine.gdoc'
# 'extempt first tournament.gdoc'
#  EYOPS
#  Fall2024_Inari_Final_Presentation.gslides
#  federal_funds_rate.csv
# 'FIDM project.gdoc'
# 'fightscene demon slayer'
# 'Final Essay Leonard Chiu P6.gdoc'
# 'final study guide 382.gdoc'
# 'First and Middle Name: Leonard.gdoc'
# 'First part of recorder way back then.m4a'
# 'first python midterm :D.gdoc'
# 'First quarter Entrepreneurship warm up and notes.gdoc'
# 'food to cook in college fr.gsheet'
# 'for bm bday post.JPG'
# 'Frat email template.gdoc'
# 'Freddie Ch1 notes.gdoc'
# 'free pass.jpg'
#  fwajiewaoijewao.gdoc
# 'Gaming for newspaper.gdoc'
# 'gatsby notes.gdoc'
# 'gatsby questions 1-7.gdoc'
# 'gatsby questions.gdoc'
#  Goals.gdoc
# 'Google AI Studio'
#  Gould_Trumpet2_LeonardChiu_audio
# 'GOW question .gdoc'
# 'GRE notes.gdoc'
# 'GRE quant notes.gdoc'
# 'Group 3 Bibliography.gdoc'
# 'Gun ownership topic.gdoc'
# "Harambe's  Code.gdoc"
# 'Hashtag Gemini Prompting.gslides'
# 'HI kick me.gdoc'
# 'History Questions.gdoc'
# 'Homecoming Fight Scene form.gform'
# 'Homecoming Freshman Auditions (File responses)'
# 'Homecoming Freshman Auditions.gform'
# 'How to play with a *bronze* vayne main.gslides'
# 'https:  images..txt'
# 'hunting for 2026 summer internship rahh.gsheet'
# 'HWK FOR THIS WEEK.gdoc'
# 'I8 Peer Review.gdoc'
# 'I am young and I am lazy assignment.gdoc'
#  ideas..gdoc
# 'identity paragraphs .gdoc'
#  image0-19.jpg
#  IMG_0688.MOV
#  IMG_0689.MOV
#  IMG_0696.MOV
# 'IMG_20190513_213656 (1).jpg'
# 'IMG_20190513_213656 (2).jpg'
#  IMG_20190513_213656.jpg
#  IMG_20190716_173943.jpg
#  IMG_20200512_124948.jpg
#  IMG_20200927_174932.jpg
#  IMG_20200927_211427.jpg
#  IMG_20200927_211429.jpg
#  IMG_20200927_211435.jpg
#  IMG_20200930_103504.jpg
#  IMG_20220518_233523.jpg
#  IMG_4967.HEIC
#  inbound2834638324839762226.jpg
#  inbound2860496013445937231.jpg
#  inbound5129973092859835653.jpg
#  inbound514918886336796408.jpg
#  inbound5474811216818165134.jpg
#  inbound5988794140522831915.jpg
#  inbound7288247241867407763.mp4
#  inflation.csv
#  InShot_20190306_160328328.mp4
#  insurance.csv
#  Interview.gdoc
# 'interview master doc.gdoc'
# 'interview prep.gdoc'
# 'introduction to poetry boegman.jpg'
# 'Intro paragraph TSOR.gdoc'
# 'Ionic bonding notes.gdoc'
# 'Isabella lullaby part 1.m4a'
# 'Isabellas lullaby part 2.m4a'
# 'Is Bella’s lullaby part 3.m4a'
# 'ishaan kar walker essay.gdoc'
# 'Israel Cards.gdoc'
# 'israeli homework hard ones.gdoc'
# 'Israeli notes #2.gdoc'
# 'Israeli topic Argumjents.gdoc'
# 'Israeli topic neg case.gdoc'
# 'Israel-Palestine conflict notes The United States should no longer pressure israel to work a two-state solution.gdoc'
# 'IU writing supplement.gdoc'
# 'i want you to generate an excel spreadsheet. For....gsheet'
# 'January pf topic notes: In order to better respond to international conflicts, the US should significantly increase its military spending.gdoc'
# 'January Public Forum cards pro.gdoc'
# '"Jean" Poem Analysis.gdoc'
# ' "Jean" Poem Analysis Leonard Chiu.gdoc'
# 'jean poem.jpg'
# 'John Proctor analysis outline.gdoc'
# 'Johnson and Johnson cover letter Leonard Chiu.gdoc'
# 'Kingdom Hearts Leonard Chiu AO.m4a'
# 'L10-2_small groupl.pptx'
# 'laika dog short story.gdoc'
# 'LAP assignment.gdoc'
# 'last hw for 305.gdoc'
# 'Last TSOR questionsxx.gdoc'
# 'laufey trumpet.gdoc'
# 'leader questions f451.gdoc'
# 'Leal Way 3.m4a'
# 'Leal Way.m4a'
# 'Len C'\''s g+ comment overload (1).jpg'
# 'Len C - Untitled (1).m4a'
# 'Len C - Untitled (2).m4a'
# 'Len C - Untitledf.m4a'
# 'Len C - Untitled.m4a'
# 'len got that drip.gsheet'
# 'Leonard Chiu Blood toil tears and sweat speech essay.gdoc'
# 'Leonard Chiu Book II 357a-369b3 questions.gdoc'
# 'Leonard Chiu Common App Essay.gdoc'
# 'Leonard Chiu Common App.gdoc'
# 'Leonard Chiu Compare and Contrast CTBC intros.gdoc'
# 'Leonard Chiu Delta Sigma Pi Questions for Brothers .gdoc'
# 'Leonard Chiu Delta Sigma Pi Questions for Executives.gdoc'
# 'Leonard Chiu Draft Affirmative action.gdoc'
# 'Leonard Chiu Duckworth v. Lee Analysis.gdoc'
# 'Leonard Chiu Essay 2.gdoc'
# 'Leonard Chiu fco Letter.gdoc'
# 'Leonard Chiu final UC Doc.gdoc'
# 'Leonard Chiu for Freshman Secretary.gdoc'
# "Leonard Chiu Hero's Journey.gslides"
# 'Leonard Chiu Interview Project.gslides'
# 'Leonard Chiu Intro to Lang. Intel. notes.gdoc'
# 'Leonard Chiu IU Supplemental Essay.gdoc'
# 'Leonard Chiu LINK crew form.gdoc'
# 'Leonard Chiu Meryl Streep Analysis.gdoc'
# 'Leonard Chiu Night and Universe of Obligation Essay .gdoc'
# 'Leonard Chiu OPTIC Assignment.gdoc'
# 'Leonard Chiu P6 2 Column Chart for Night.gdoc'
# 'Leonard Chiu P6 Rhetoric articles assignment.gdoc'
# 'Leonard Chiu P6 Seven Times Cursed Paragraph.gdoc'
# 'Leonard Chiu p6 Universe of Obligation Essay.gdoc'
# 'Leonard Chiu Period 6 Goal Setting.jpg'
# 'Leonard Chiu questions for Wednesday 8 30.gdoc'
# 'Leonard Chiu Reading for Friday 9 1 Quesitons.gdoc'
# 'Leonard Chiu_Resume (1).pdf'
# 'Leonard Chiu Resume.docx'
# 'Leonard Chiu_Resume.docx'
# 'Leonard Chiu Resume.gdoc'
# 'Leonard Chiu_Resume.pdf'
# 'Leonard Chiu Revised Churchill Speech Essay.gdoc'
# 'Leonard Chiu seinor profile.gdoc'
#  Leonard_Chiu_Sponsorship_Tiers_Jigsaw_Puzzle.gdoc
# "Leonard Chiu's Resume .pdf"
# 'Leonard Chiu Tesla SWOT Analysis.gdoc'
# 'Leonard Chiu UIUC.gdoc'
# 'Leonard Chiu UW Madison.gdoc'
# 'Leonard Purdue Supplementals.gdoc'
# 'Leonard UC Q1  v2.gdoc'
# 'Leonard USC Supplemental.gdoc'
# 'Lesson 1 Diagnostic.gform'
# 'Limericks Leonard Chiu Period 6.gdoc'
# 'lincoln essay.gdoc'
# 'link crew application form.gdoc'
# 'Lit Circle #2 Summarizer and Connector Leonard Chiu.gdoc'
#  Lookbook.gslides
#  magwitch.gdoc
# 'manifest destiny .gdoc'
# 'march marketing terms.gdoc'
# 'march marketing test cheat sheet.gdoc'
# 'Marigolds questions.gdoc'
#  Market_Data.csv
# 'Master key'
# 'MDG essay.gdoc'
# 'Meals to cook.gsheet'
# 'mending wall.jpg'
# "Merry-Go-Round of Life: Howl's Moving Castle Piano Tutorial "
# 'MGMT 254 .gdoc'
# 'MGMT 382 Final Project: AI in NBA.gslides'
# 'MGMT 388 notes.gdoc'
#  MGMT467
# 'mgmt 473 notes.gdoc'
# 'microecon notes.gdoc'
# 'midterm 2 study guide 305.gdoc'
#  miku.txt
# 'mile times.gsheet'
# 'Military spending Pro case.gdoc'
# 'mock question answers.gdoc'
# 'modernism notes.gdoc'
# "mom's theory stuff.gdoc"
# 'mr. boegman letter.gdoc'
# 'mr boegman second penpal.gdoc'
# "Msimangu's Thesis Leonard Chiu.gdoc"
# ' MSJ  ED COLLEGE DECISIONS.gsheet'
# 'musescore for a supp that steals kills (apc).gdoc'
# 'MushroomCloud_LuigiAndMario (1).pdf'
# 'My recording #4.wav'
# 'My recording #5 (1).wav'
# 'My recording #5.wav'
# 'My SAT Home Page.pdf'
#  Name:________________________________________Period:__________Date:__________.gdoc
# 'national and electoral notes.gdoc'
# 'national popular vote and electoral college two articles.gdoc'
# 'new london paragraph.gdoc'
# 'New Recording 14.m4a'
# 'New Recording 16.m4a'
# 'New Recording 17.m4a'
# 'newspaper articles for boteilho sigh.gdoc'
#  notes.gdoc
# "notes that i can't really take bc the seniors were changing slides too quick.gdoc"
# 'nutrition quiz 3 notes.gdoc'
# 'nutrition test doc.gdoc'
# 'OBHR 330 notes.gdoc'
# 'obhr 330 project.gdoc'
# 'o captain my captain.jpg'
# 'Of MIce and Men Essay.gdoc'
# 'og squad form v2.gform'
# "Our employee's emails.gdoc"
# 'outline john proctor.gdoc'
#  P1030014.JPG
#  P1030063.JPG
#  P1030445.JPG
#  P1030474.JPG
#  P1030511.JPG
#  P1030544.JPG
#  P1030545.JPG
#  P1030546.JPG
#  P1030547.JPG
#  P1030548.JPG
#  P1030549.JPG
#  P1030550.JPG
#  P1030551.JPG
#  P1030552.JPG
#  P1030553.JPG
#  P1030554.JPG
#  P1030555.JPG
#  P1030556.JPG
#  P1030557.JPG
#  P1030559.JPG
#  P1030561.JPG
#  P1030562.JPG
#  P1030563.JPG
#  P1030564.JPG
#  P1030565.JPG
#  P1030566.JPG
#  P1030567.JPG
#  P1030568.JPG
#  P1030570.JPG
#  P1030571.JPG
#  P1030572.JPG
#  P1030573.JPG
#  P1030575.JPG
#  P1030576.JPG
#  P1030584.JPG
#  P1030585.JPG
#  P1030586.JPG
#  P1030587.JPG
#  P1030588.JPG
#  P1030589.JPG
#  P1040087.JPG
#  P1040088.JPG
# 'Passage master.gdoc'
# 'Passage Master Red Scarf Girl Lit Circle #5.gdoc'
# 'pe pt 3.gdoc'
# 'Pe Pt4.gdoc'
# 'persia planner for projecto.gdoc'
# 'phenomenal woman.jpg'
# '"Phenomenal Women" Poem Analysis.gdoc'
# 'photography magazine.gdoc'
# 'photography project....gdoc'
# 'Photo of the month.gdoc'
# 'photos for ascend case comp'
# 'PIANO TEACHER.gdoc'
# 'planets notes.gdoc'
# 'Plans and Counterplans.gdoc'
# 'Plato V Leonard Chiu questions.gdoc'
# 'Poetry Portfolio'
# 'Poetry Portfolio Poem examples.gdoc'
# 'portfolio cover.jpg'
#  PortfolioManagement.ipynb
#  Potter_trumpet_Leonard2.jpg
#  Potter_trumpet_Leonard3.jpg
#  Potter_trumpet_Leonard.jpg
# 'Practice Body Paragraph.gdoc'
# 'Prairie Equipment Leonard Chiu.gdoc'
# 'Premium Pricing Strategy Report.gsheet'
# 'Presentation Leonard Chiu.gslides'
# 'Pro Case Cuban Embargo.gdoc'
# 'proctor essay outline.gdoc'
# 'Pro Debate Case.gdoc'
# 'professional photography SAT essay.gdoc'
# 'Pronoun Errors.gdoc'
# 'psych terms and stuff.gdoc'
#  PXL_20201106_220105944.jpg
#  PXL_20210117_00403204.jpg
#  PXL_20210326_194911940l.jpg
#  PXL_20210326_194921029.jpg
#  PXL_20210416_194319488.jpg
# 'PXL_20210416_194344988 (1).jpg'
#  PXL_20210416_194344988.jpg
#  PXL_20210418_225139942.mp4
#  PXL_20210606_062400845.jpg
#  PXL_20210628_201444300.jpg
#  PXL_20210828_022605533.jpg
#  PXL_20210828_022609696.jpg
#  PXL_20210828_034804899.jpg
#  PXL_20211030_065126975.jpg
#  PXL_20220217_010222704.jpg
#  PXL_20220303_013954027_exported_7251.jpg
#  PXL_20220305_015438714.jpg
#  PXL_20220429_021605000.jpg
#  PXL_20220429_234548193.MP.jpg
#  PXL_20240616_063334095.TS.mp4
#  PXL_20250114_044230611.mp4
#  PXL_20250329_024817085.MP.jpg
# 'Python sample test questions.gdoc'
# 'Q4 marketing warmups.gdoc'
# 'quarantine fitness journal log.gdoc'
# 'Quarter 2 Marketing warm ups.gdoc'
# 'quiz 3.gdoc'
# 'quiz bill gates etc.gdoc'
#  quotes.gdoc
# 'qurantine fitness journal pt 2.gdoc'
# 'random serv.gform'
# 'random serv (Responses).gsheet'
#  raw
# 'Ray history doc.gdoc'
# 'read article read essay write list of important points teacher left out.gdoc'
# 'Reading and Writing Test Review Packet (2).gdoc'
#  Rebuttal.gdoc
#  received_1164337230657883.jpeg
#  received_1225573218213823.jpeg
#  received_1299159370583416.jpeg
#  received_146841987387354.jpeg
#  received_1577806682426997.jpeg
#  received_1661923887509061.jpeg
#  received_1835859469929181.mp4
#  received_192113709460920.jpeg
#  received_210052767611967.jpeg
# 'received_285581443305174 (1).jpeg'
#  received_285581443305174.jpeg
# 'received_343963027168948 (1).jpeg'
#  received_343963027168948.jpeg
#  received_396952128968445.jpeg
#  received_448879007049371.jpeg
# 'received_507961070541019 (1).jpeg'
#  received_507961070541019.jpeg
#  received_529368065084533.jpeg
#  received_532077291684314.jpeg
#  received_537768644579475.jpeg
#  received_708804933650873.jpeg
#  received_735952701118210.jpeg
#  received_956507298467137.jpeg
# 'recipe book.gdoc'
# 'Recipe for snickers bar.gdoc'
#  Recipe.gdoc
# 'Red Scarf Girl Lit Circle #1 Discussion Director.gdoc'
# 'Red Scarf Girl Master of Metaphor Lit Circle #6.gdoc'
# 'Reflection .gdoc'
# 'Rejouissance Leonard Chiu AO'
# 'Resolution(Israel) def.gdoc'
# 'Riding My Bike Free Verse.gdoc'
# 'romeo and juliet stanza #1.jpg'
# 'romeo and juliet stanza #2.jpg'
# 'romeo and juliet stanza #3.jpg'
# 'Rostow Stage APHG FRQ.gdoc'
# 'SAAD AMIN STSTA CARYARYRY.gdoc'
# 'Safety video Flores 10 facts.gdoc'
# "Sasan's MENTAL HEALTH CONTENTION.gdoc"
# 'sat plastic bag essay.gdoc'
# 'SCDC Negative COVID Test Submission (Feb 23, 2022 4:39:57 PM).jpeg'
#  Screenshot_20210628-131231.png
#  Screenshot_20220107-103659.png
#  Screenshot_20240201-205050.png
# 'Screenshot 2025-02-16 112742.png'
# 'script for travel vlog.gdoc'
# 'Second part of recorder way back then.m4a'
# 'shared doc resume.gdoc'
# 'short stories notes.gdoc'
#  sjsjja.jpg
# 'SMG but actually try maybe.gdoc'
# 'Social Advertising Business Model .gsheet'
# 'Socrates Essay.gdoc'
# 'SOVA LINEUPS.gdoc'
#  sp500_index.csv
# 'spanish projecto.gdoc'
#  SpongeBob_beginning_theme_for_hoco.pdf
# 'Sports Physical Page 1.pdf'
# 'Sports Physical Page 2.pdf'
# 'Sports Physical Page 3.pdf'
# 'stardew necessary food.gsheet'
# 'stonks?.gsheet'
# "Streep's Powerful Speech Leonard Chiu Period 6.gdoc"
# 'stupid econ budget project.gdoc'
#  submission_220034528.pdf
# 'summary notes.gdoc'
# 'Summer Remorses - Leonard Chiu.gdoc'
# 'Taiwan 2024.gsheet'
# 'take care of urself bro.gdoc'
# 'TAMU supplementals.gdoc'
# 'TC03 Test Review Packet.gdoc'
# 'TC-04 Review Packet.gdoc'
# 'TC08 Test Review Packet.gdoc'
# 'Team 3 MGMT 382 Final project AI in NBA.pptx'
# 'teddy roosevelt poster.gdoc'
# 'Test Review Packet TB13.gdoc'
#  Themes.gdoc
# 'The Pearl Images.gdoc'
# 'the spot.gdoc'
# 'The Value of Studying Literature Leonard Chiu.gdoc'
# 'The Value of Studying Literature Writing Prompt.gdoc'
# 'the zebra storyteller first and fourth paragraph.gdoc'
#  tips.csv
# 'tkam essay boegman.gdoc'
#  tologwordpro0502lp.pdf
# 'too many angels.jpg'
# 'Top 5 vines in the class.gdoc'
# 'Topic 1 Resources (Probable Cause)'
# 'Toyota Assignment.gdoc'
# 'TRACK 2022 SENIOR NIGHT PLANNING.gsheet'
# 'Track Medals Name List.gdoc'
# 'track preseason baby.gsheet'
# 'TRACK SENIOR NIGHT 2022 checklist.gdoc'
# 'track workout log.gdoc'
# 'Translated copy of Pre-MVP Interviews Takeaway.gdoc'
# 'Translated copy of 關鍵Highlights.gdoc'
#  TRIM_20190511_134751.mp4
# 'Trombone D.m4a'
# 'Trombone E.m4a'
# 'Trombone G.m4a'
# 'Truman Doctrine.gsite'
# 'TSOR speech thingy.gdoc'
# 'Tutoring hours log.gsheet'
# 'Two Presidents Textbook Questions.gdoc'
# 'Two-state solution week 1 homework.gdoc'
# 'UC Activites.gdoc'
# 'UC Davis LOCI.gdoc'
# 'UC Essays Leonard Chiu.gdoc'
# 'UC Q2 V2 (1).gdoc'
# 'UC Q2 V2.gdoc'
# 'UC Q8 V1 (1).gdoc'
# 'UC Q8 V1.gdoc'
# 'Ukulele way back then.m4a'
# 'under the harvest moon.PNG'
# 'Unit 6 online discussion.gdoc'
# 'Untitled document (100).gdoc'
# 'Untitled document (101).gdoc'
# 'Untitled document (102).gdoc'
# 'Untitled document (103).gdoc'
# 'Untitled document (104).gdoc'
# 'Untitled document (105).gdoc'
# 'Untitled document (106).gdoc'
# 'Untitled document (107).gdoc'
# 'Untitled document (108).gdoc'
# 'Untitled document (109).gdoc'
# 'Untitled document (10).gdoc'
# 'Untitled document (110).gdoc'
# 'Untitled document (111).gdoc'
# 'Untitled document (112).gdoc'
# 'Untitled document (113).gdoc'
# 'Untitled document (114).gdoc'
# 'Untitled document (115).gdoc'
# 'Untitled document (116).gdoc'
# 'Untitled document (117).gdoc'
# 'Untitled document (118).gdoc'
# 'Untitled document (119).gdoc'
# 'Untitled document (11).gdoc'
# 'Untitled document (120).gdoc'
# 'Untitled document (121).gdoc'
# 'Untitled document (122).gdoc'
# 'Untitled document (123).gdoc'
# 'Untitled document (124).gdoc'
# 'Untitled document (125).gdoc'
# 'Untitled document (126).gdoc'
# 'Untitled document (127).gdoc'
# 'Untitled document (128).gdoc'
# 'Untitled document (129).gdoc'
# 'Untitled document (12).gdoc'
# 'Untitled document (130).gdoc'
# 'Untitled document (131).gdoc'
# 'Untitled document (132).gdoc'
# 'Untitled document (133).gdoc'
# 'Untitled document (134).gdoc'
# 'Untitled document (135).gdoc'
# 'Untitled document (136).gdoc'
# 'Untitled document (137).gdoc'
# 'Untitled document (138).gdoc'
# 'Untitled document (139).gdoc'
# 'Untitled document (13).gdoc'
# 'Untitled document (140).gdoc'
# 'Untitled document (141).gdoc'
# 'Untitled document (142).gdoc'
# 'Untitled document (143).gdoc'
# 'Untitled document (144).gdoc'
# 'Untitled document (145).gdoc'
# 'Untitled document (146).gdoc'
# 'Untitled document (147).gdoc'
# 'Untitled document (148).gdoc'
# 'Untitled document (149).gdoc'
# 'Untitled document (14).gdoc'
# 'Untitled document (150).gdoc'
# 'Untitled document (151).gdoc'
# 'Untitled document (152).gdoc'
# 'Untitled document (153).gdoc'
# 'Untitled document (154).gdoc'
# 'Untitled document (155).gdoc'
# 'Untitled document (156).gdoc'
# 'Untitled document (157).gdoc'
# 'Untitled document (158).gdoc'
# 'Untitled document (159).gdoc'
# 'Untitled document (15).gdoc'
# 'Untitled document (160).gdoc'
# 'Untitled document (161).gdoc'
# 'Untitled document (162).gdoc'
# 'Untitled document (163).gdoc'
# 'Untitled document (164).gdoc'
# 'Untitled document (165).gdoc'
# 'Untitled document (166).gdoc'
# 'Untitled document (167).gdoc'
# 'Untitled document (16).gdoc'
# 'Untitled document (17).gdoc'
# 'Untitled document (18).gdoc'
# 'Untitled document (19).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (20).gdoc'
# 'Untitled document (21).gdoc'
# 'Untitled document (22).gdoc'
# 'Untitled document (23).gdoc'
# 'Untitled document (24).gdoc'
# 'Untitled document (25).gdoc'
# 'Untitled document (26).gdoc'
# 'Untitled document (27).gdoc'
# 'Untitled document (28).gdoc'
# 'Untitled document (29).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (30).gdoc'
# 'Untitled document (31).gdoc'
# 'Untitled document (32).gdoc'
# 'Untitled document (33).gdoc'
# 'Untitled document (34).gdoc'
# 'Untitled document (35).gdoc'
# 'Untitled document (36).gdoc'
# 'Untitled document (37).gdoc'
# 'Untitled document (38).gdoc'
# 'Untitled document (39).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (40).gdoc'
# 'Untitled document (41).gdoc'
# 'Untitled document (42).gdoc'
# 'Untitled document (43).gdoc'
# 'Untitled document (44).gdoc'
# 'Untitled document (45).gdoc'
# 'Untitled document (46).gdoc'
# 'Untitled document (47).gdoc'
# 'Untitled document (48).gdoc'
# 'Untitled document (49).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (50).gdoc'
# 'Untitled document (51).gdoc'
# 'Untitled document (52).gdoc'
# 'Untitled document (53).gdoc'
# 'Untitled document (54).gdoc'
# 'Untitled document (55).gdoc'
# 'Untitled document (56).gdoc'
# 'Untitled document (57).gdoc'
# 'Untitled document (58).gdoc'
# 'Untitled document (59).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (60).gdoc'
# 'Untitled document (61).gdoc'
# 'Untitled document (62).gdoc'
# 'Untitled document (63).gdoc'
# 'Untitled document (64).gdoc'
# 'Untitled document (65).gdoc'
# 'Untitled document (66).gdoc'
# 'Untitled document (67).gdoc'
# 'Untitled document (68).gdoc'
# 'Untitled document (69).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (70).gdoc'
# 'Untitled document (71).gdoc'
# 'Untitled document (72).gdoc'
# 'Untitled document (73).gdoc'
# 'Untitled document (74).gdoc'
# 'Untitled document (75).gdoc'
# 'Untitled document (76).gdoc'
# 'Untitled document (77).gdoc'
# 'Untitled document (78).gdoc'
# 'Untitled document (79).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (80).gdoc'
# 'Untitled document (81).gdoc'
# 'Untitled document (82).gdoc'
# 'Untitled document (83).gdoc'
# 'Untitled document (84).gdoc'
# 'Untitled document (85).gdoc'
# 'Untitled document (86).gdoc'
# 'Untitled document (87).gdoc'
# 'Untitled document (88).gdoc'
# 'Untitled document (89).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (90).gdoc'
# 'Untitled document (91).gdoc'
# 'Untitled document (92).gdoc'
# 'Untitled document (93).gdoc'
# 'Untitled document (94).gdoc'
# 'Untitled document (95).gdoc'
# 'Untitled document (96).gdoc'
# 'Untitled document (97).gdoc'
# 'Untitled document (98).gdoc'
# 'Untitled document (99).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled form (1).gform'
# 'Untitled form (2).gform'
# 'Untitled form (3).gform'
# 'Untitled form (4).gform'
# 'Untitled form (5).gform'
# 'Untitled form (6).gform'
# 'Untitled form (7).gform'
# 'Untitled form (8).gform'
# 'Untitled form (9).gform'
# 'Untitled form.gform'
# 'Untitled form (Responses).gsheet'
# 'Untitled map.gmap'
# 'Untitled presentation (10).gslides'
# 'Untitled presentation (1).gslides'
# 'Untitled presentation (2).gslides'
# 'Untitled presentation (3).gslides'
# 'Untitled presentation (4).gslides'
# 'Untitled presentation (5).gslides'
# 'Untitled presentation (6).gslides'
# 'Untitled presentation (7).gslides'
# 'Untitled presentation (8).gslides'
# 'Untitled presentation (9).gslides'
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet (10).gsheet'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet (4).gsheet'
# 'Untitled spreadsheet (5).gsheet'
# 'Untitled spreadsheet (6).gsheet'
# 'Untitled spreadsheet (7).gsheet'
# 'Untitled spreadsheet (8).gsheet'
# 'Untitled spreadsheet (9).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'USA GDP Growth 1961-2021.csv'
# 'USA GDP Growth 1961-2021.xlsx'
# 'USC supplemental questions.gdoc'
# 'UX interview planning.gdoc'
#  V4:.gdoc
# "valentine's day writing tutor assingments.gdoc"
# 'VERY VERY VERY IMPORTANT NOTES FOR CUBAN TOPIC DEBATE.gdoc'
#  VID_20200919_160933_exported_884_1600565244525.jpg
# 'VID_20200919_162722~2 (1).mp4'
#  VID_20200919_162722~2.mp4
#  VID_20200919_162845~2_exported_313_1600655090454.jpg
# 'VID_20200919_162845~2_exported_8846_1600565785333 (1).jpg'
#  VID_20200919_162845~2_exported_8846_1600565785333.jpg
#  VID_20200919_163722~2.mp4
#  VID_20200919_164318~2.mp4
# 'Vinay interview presentation script.gdoc'
# 'Viva_La_Vida-Duet(Trumpet-Trumpet).mscz'
# ' wagner questions.gdoc'
# 'walt whitman.jpg'
# '"what did you do" question for interviews.gdoc'
# 'What is John Proctor.gdoc'
# 'WHAT TO BUY TAIWAN 2024.gsheet'
# 'where I'\''m from (1).jpg'
# "where I'm from.jpg"
# "Where I'm from poem Leonard Chiu.gdoc"
# 'workout planner.gsheet'
# 'workouts for the week.gsheet'
# 'World History notes ig.gdoc'
# 'Writing Sample (1).gdoc'
# 'Writing Sample (2).gdoc'
# 'Writing Sample (3).gdoc'
# 'Writing Sample (4).gdoc'
# 'Writing Sample (Corrected Sentence).gdoc'
# 'Writing Sample.gdoc'
# "writing tutor's homework 2 20.gdoc"
# "yeah yeah we'll get it one day.gsheet"
#  yes.gdoc
# 'yongkang fun.gmap'
# 'Yummo Business Model.gdoc'

# %% [markdown]
# ## 3. Authenticate GCP in Colab

# %%
from google.colab import auth
auth.authenticate_user()

print("Authenticated to GCP successfully!")
# Out:
# Authenticated to GCP successfully!

# %% [markdown]
# Once authenticated, you can access BigQuery and other GCP services from this notebook.

# %% [markdown]
# ## 4. Run a BigQuery Sanity Query

# %%
from google.cloud import bigquery

# Create a BigQuery client
client = bigquery.Client(project="mgmt-467-4677")

# Simple test query: public dataset
query = "SELECT name, SUM(number) as total FROM `bigquery-public-data.usa_names.usa_1910_2013` GROUP BY name ORDER BY total DESC LIMIT 5"
results = client.query(query).to_dataframe()

results
# Out:
#       name    total
# 0    James  4942431
# 1     John  4834422
# 2   Robert  4718787
# 3  Michael  4297230
# 4  William  3822209

# %% [markdown]
# ## 5. Save Notebook to GitHub

# %% [markdown]
# To push from Colab to GitHub, you can use a **personal access token (PAT)**.
#
# **Steps:**
# 1. On GitHub, go to **Settings → Developer settings → Personal access tokens (classic)**.
# 2. Generate a token with `repo` permissions (set expiry to ~7 days for safety).
# 3. In Colab, use the snippet below to push your notebook back to GitHub.
#
# :warning: Do **NOT** hardcode tokens in notebooks. Use `getpass` to input securely.

# %%
import os
from getpass import getpass

# Enter your GitHub credentials
username = "LeonardChiu567"
token = getpass("Enter your GitHub token: ")
repo = "mgmt467-analytics-portfolio"  # e.g., MGMT467_TeamX
notebook_filename = "Week2_2_Git_Colab_GCP_Lab.ipynb"

# Save notebook to GitHub
# !git config --global user.name "{username}"
# !git config --global user.email "{username}@users.noreply.github.com"

# Copy notebook into repo
# !cp /content/drive/MyDrive/Colab\ Notebooks/{notebook_filename} Labs/

# Commit and push
# !cd {repo} && git add . && git commit -m "Added Week 2.2 Lab notebook" && git push
# Out:
# Enter your GitHub token: ··········
# cp: cannot create regular file 'Labs/': Not a directory
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ## ✅ Exit Ticket

# %% [markdown]
# Before you leave, make sure you have:
# - [ ] Mounted Google Drive in Colab
# - [ ] Authenticated to GCP successfully
# - [ ] Run the BigQuery sanity check
# - [ ] Saved your notebook to your team GitHub repo
#
# Upload your GitHub repo link to Brightspace as proof of completion.
